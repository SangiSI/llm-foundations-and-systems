# %%
import sys, pyarrow, datasets, evaluate
print(sys.version)
print("pyarrow:", pyarrow.__version__)
print("datasets:", datasets.__version__)
print("evaluate:", evaluate.__version__)
# Out:
# 3.10.19 (main, Dec 17 2025, 09:52:23) [Clang 12.0.0 (clang-1200.0.32.29)]
# pyarrow: 11.0.0
# datasets: 2.16.1
# evaluate: 0.4.6
